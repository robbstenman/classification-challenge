# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# 1             0.00            0.94  ...         0.00        0.132
# 2             0.64            0.25  ...         0.01        0.143
# 3             0.31            0.63  ...         0.00        0.137
# 4             0.31            0.63  ...         0.00        0.135
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0          0.0        0.778        0.000        0.000
# 1          0.0        0.372        0.180        0.048
# 2          0.0        0.276        0.184        0.010
# 3          0.0        0.137        0.000        0.000
# 4          0.0        0.135        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       3.756                          61
# 1                       5.114                         101
# 2                       9.821                         485
# 3                       3.537                          40
# 4                       3.537                          40
#
#    capital_run_length_total  spam
# 0                       278     1
# 1                      1028     1
# 2                      2259     1
# 3                       191     1
# 4                       191     1
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# Prediction: I think Logistic Regression will be more effective. The email is either spam or not spam. Logistic regression is good at categorizing items into two groups.

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`

y = data['spam']

X = data.copy()
X = X.drop(columns='spam')

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
data['spam'].value_counts()
# Out:
# spam
# 0    2788
# 1    1813
# Name: count, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y)

X_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 873             0.00               0.19           0.57           0.0
# 2960            0.00               0.00           0.00           0.0
# 1499            0.00               0.00           0.47           0.0
# 2783            0.00               0.00           0.00           0.0
# 3127            0.00              14.28           0.00           0.0
# ...              ...                ...            ...           ...
# 1086            0.17               0.00           0.17           0.0
# 401             1.05               0.00           0.70           0.0
# 2014            0.00               0.00           0.00           0.0
# 3096            0.00               0.00           0.00           0.0
# 8               0.15               0.00           0.46           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 873            0.09            0.28              0.09                0.09
# 2960           0.00            0.00              0.00                0.00
# 1499           1.43            0.00              0.00                0.00
# 2783           0.00            0.00              0.00                0.00
# 3127           0.00            0.00              0.00                0.00
# ...             ...             ...               ...                 ...
# 1086           1.52            0.35              0.05                0.05
# 401            1.05            0.00              0.70                0.00
# 2014           0.00            0.00              0.00                0.00
# 3096           0.00            0.00              0.00                0.00
# 8              0.61            0.00              0.30                0.00
#
#       word_freq_order  word_freq_mail  ...  word_freq_conference  char_freq_;  \
# 873              0.38            0.19  ...                   0.0        0.035
# 2960             0.00            0.00  ...                   0.0        0.000
# 1499             0.00            0.00  ...                   0.0        0.000
# 2783             0.00            0.00  ...                   0.0        0.000
# 3127             0.00            0.00  ...                   0.0        0.000
# ...               ...             ...  ...                   ...          ...
# 1086             0.05            0.05  ...                   0.0        0.010
# 401              0.00            0.35  ...                   0.0        0.000
# 2014             0.00            0.00  ...                   0.0        0.000
# 3096             0.00            0.00  ...                   0.0        0.000
# 8                0.92            0.76  ...                   0.0        0.000
#
#       char_freq_(  char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 873         0.230          0.0        0.088        0.124        0.000
# 2960        0.555          0.0        0.000        0.000        0.000
# 1499        0.076          0.0        0.536        0.306        0.000
# 2783        0.408          0.0        0.000        0.000        0.000
# 3127        0.000          0.0        0.000        0.000        0.000
# ...           ...          ...          ...          ...          ...
# 1086        0.052          0.0        0.010        0.167        0.000
# 401         0.000          0.0        0.367        0.061        0.000
# 2014        0.018          0.0        0.000        0.000        0.000
# 3096        0.135          0.0        0.406        0.000        0.135
# 8           0.271          0.0        0.181        0.203        0.022
#
#       capital_run_length_average  capital_run_length_longest  \
# 873                        2.405                          50
# 2960                       1.647                           4
# 1499                       4.653                          78
# 2783                       2.125                          17
# 3127                       1.800                           5
# ...                          ...                         ...
# 1086                       1.838                          13
# 401                        1.880                          12
# 2014                     251.000                        1488
# 3096                       1.958                          17
# 8                          9.744                         445
#
#       capital_run_length_total
# 873                        368
# 2960                        28
# 1499                       242
# 2783                        51
# 3127                         9
# ...                        ...
# 1086                       467
# 401                         94
# 2014                      1506
# 3096                        94
# 8                         1257
#
# [3450 rows x 57 columns]

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the Standard Scaler with the training data
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the training data
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score
from sklearn.linear_model import LogisticRegression
logistic_regression_model = LogisticRegression(random_state=1)
logistic_regression_model.fit(X_train_scaled, y_train)

print(f"Training Data Score: {logistic_regression_model.score(X_train_scaled, y_train)}")
# Out:
# Training Data Score: 0.9342028985507247

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
testing_predections = logistic_regression_model.predict(X_test_scaled)

# Review the predictions
testing_predections
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.

lr_accuracy_score = accuracy_score(y_test, testing_predections)
lr_accuracy_score
# Out:
# 0.9148566463944396

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=1)
rf_model.fit(X_train_scaled, y_train)

print(f"Training Data Score: {rf_model.score(X_train_scaled, y_train)}")
# Out:
# Training Data Score: 0.9991304347826087

# %%
# Make and save testing predictions with the saved logistic regression model using the test data
rf_testing_predections = rf_model.predict(X_test_scaled)

# Review the predictions
rf_testing_predections
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.

rf_accuracy_score = accuracy_score(y_test, rf_testing_predections)
rf_accuracy_score
# Out:
# 0.9530842745438749

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# The Random Forest model performed better than the Logistic Regression model. Both models were good, but the Random Forest accuracy score was higher than the Logistic Regression accuracy score. My prediction was incorrect. I was looking mainly at the output being binary so thought that the Logistic Regressoin model would be better. Upon further reflection, I think the Random Forest model was better because there are several different types of spam emails. Random Forest was better and evaluating each different type of email and categorize it as either spam or not spam.
